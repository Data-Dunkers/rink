# %% [markdown]
# ![Banner](https://github.com/Data-Dunkers/lessons/blob/main/images/top-banner.jpg?raw=true)

# %% [markdown]
# # Interpreting Scatterplots
#
# Scatterplots are used to show the relationship between two different variables. In this lesson, we'll see if there's a relationship between how many **points** a player scores and how **efficient** they are at shooting.
#
# We'll use a dataset of 2024-2025 NHL player statistics. We are looking at `PTS` (Points Per Game) vs `FG%` (Field Goal Percentage).

# %%
import pandas as pd
import plotly.express as px

url = "https://raw.githubusercontent.com/Data-Dunkers/data/refs/heads/main/NHL/player/nhl_player_stats_2024-2025.csv"
df = pd.read_csv(url)

px.scatter(df, x='S', y='G', hover_data=['Name'], title='Shot Attempts vs Goals Per Game (NHL 2024-2025)', trendline='ols')

# %% [markdown]
# ## Reflection Questions
#
# 1. Looking at the trendline, does more shots on goal generally mean a player scores more goals? Explain.
# 2. Can you find one specific player (by hovering over the dots) that you would consider a "positive outlier" (more goals than expected for the number of shots)?
# 3. Why do you think the dots tend to be more clumped together at the bottom right?

# %% [markdown]
# ---
#
# ### Online Access
# You can run this notebook online using the following links:
#
# *   [**Google Colab**](https://colab.research.google.com/github/Data-Dunkers/rinks/blob/main/activities/interpreting-scatterplots.ipynb)
# *   [**Callysto Hub**](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FData-Dunkers%2Frinks&branch=main&subPath=activities/interpreting-scatterplots.ipynb&depth=1)
